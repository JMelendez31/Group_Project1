# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
life_expectancy = pd.read_csv('Life-Expectancy-Data-Updated.csv')
life_expectancy
# Out:
#         Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0       Turkiye     Middle East  2015           11.1               13.0
# 1         Spain  European Union  2015            2.7                3.3
# 2         India            Asia  2007           51.5               67.9
# 3        Guyana   South America  2006           32.8               40.5
# 4        Israel     Middle East  2012            3.4                4.3
# ...         ...             ...   ...            ...                ...
# 2859      Niger          Africa  2000           97.0              224.9
# 2860   Mongolia            Asia  2009           23.9               28.6
# 2861  Sri Lanka            Asia  2004           17.7               28.9
# 2862  Lithuania  European Union  2002            7.9                9.9
# 2863    Iceland  Rest of Europe  2011            2.1                2.6
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0            105.8240                1.320           97       65  27.8  ...
# 1             57.9025               10.350           97       94  26.0  ...
# 2            201.0765                1.570           60       35  21.2  ...
# 3            222.1965                5.680           93       74  25.3  ...
# 4             57.9510                2.890           97       89  27.0  ...
# ...               ...                  ...          ...      ...   ...  ...
# 2859         291.8240                0.092           72       64  20.8  ...
# 2860         235.2330                6.560           97       97  25.3  ...
# 2861         134.8950                1.560           62       95  21.9  ...
# 2862         204.0120               11.000           94       95  26.1  ...
# 2863          50.5745                6.840           88       90  26.1  ...
#
#       Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0             97           0.08           11006           78.53
# 1             97           0.09           25742           46.44
# 2             64           0.13            1076         1183.21
# 3             93           0.79            4146            0.75
# 4             94           0.08           33995            7.91
# ...          ...            ...             ...             ...
# 2859          34           0.49             399           11.33
# 2860          95           0.02            2515            2.67
# 2861          97           0.02            2130           19.39
# 2862          95           0.05            7424            3.44
# 2863          95           0.05           48934            0.32
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                             4.9                       4.8        7.8
# 1                             0.6                       0.5        9.7
# 2                            27.1                      28.0        5.0
# 3                             5.7                       5.5        7.9
# 4                             1.2                       1.1       12.8
# ...                           ...                       ...        ...
# 2859                         12.8                      12.9        1.1
# 2860                          2.2                       2.3        9.1
# 2861                         15.4                      15.5       10.3
# 2862                          3.3                       3.3       11.1
# 2863                          0.9                       0.9       11.0
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 0                            0                          1             76.5
# 1                            1                          0             82.8
# 2                            0                          1             65.4
# 3                            0                          1             67.0
# 4                            1                          0             81.7
# ...                        ...                        ...              ...
# 2859                         0                          1             49.9
# 2860                         0                          1             66.9
# 2861                         0                          1             74.3
# 2862                         1                          0             71.8
# 2863                         1                          0             82.4
#
# [2864 rows x 21 columns]

# %%
# General sample info
countries = life_expectancy['Country'].unique()
years = life_expectancy['Year'].unique()
print(len(countries))
print(len(years))
# Out:
# 179
# 16

# %%
columns = life_expectancy.columns
columns
# Out:
# Index(['Country', 'Region', 'Year', 'Infant_deaths', 'Under_five_deaths',
#        'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles',
#        'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita',
#        'Population_mln', 'Thinness_ten_nineteen_years',
#        'Thinness_five_nine_years', 'Schooling', 'Economy_status_Developed',
#        'Economy_status_Developing', 'Life_expectancy'],
#       dtype='object')

# %%
developed = life_expectancy.query('Economy_status_Developed==1')
developing = life_expectancy.query('Economy_status_Developing == 1')

# %%
developed.query("Year==2015").sort_values('Infant_deaths',ascending=True).head()
# Out:
#        Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 2442   Iceland  Rest of Europe  2015            1.8                2.3
# 1063   Finland  European Union  2015            2.0                2.5
# 1196     Japan            Asia  2015            2.0                2.7
# 1145  Slovenia  European Union  2015            2.1                2.6
# 110     Norway  Rest of Europe  2015            2.2                2.7
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 2442          55.3590                 7.66           88       94  26.2  ...
# 1063          68.8685                 8.52           88       92  25.9  ...
# 1196          53.5860                 8.55           83       93  22.7  ...
# 1145          73.3560                11.49           88       96  26.5  ...
# 110           53.8970                 5.97           88       91  26.6  ...
#
#       Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 2442          92           0.05           52952            0.33
# 1063          97           0.08           42802            5.48
# 1196          96           0.17           34961          127.14
# 1145          95           0.01           20890            2.06
# 110           95           0.04           74356            5.19
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 2442                          1.0                       0.9       12.2
# 1063                          0.9                       0.8       12.4
# 1196                          2.1                       1.8       12.5
# 1145                          1.4                       1.3       12.0
# 110                           0.8                       0.7       12.5
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 2442                         1                          0             82.5
# 1063                         1                          0             81.5
# 1196                         1                          0             83.8
# 1145                         1                          0             80.8
# 110                          1                          0             82.3
#
# [5 rows x 21 columns]

# %%
developing.query("Year==2015").sort_values('Infant_deaths',ascending=True).head()
# Out:
#          Country                         Region  Year  Infant_deaths  \
# 2080   Singapore                           Asia  2015            2.2
# 202      Belarus                 Rest of Europe  2015            3.1
# 1530  Montenegro                 Rest of Europe  2015            3.3
# 2127        Cuba  Central America and Caribbean  2015            4.5
# 1715      Serbia                 Rest of Europe  2015            5.4
#
#       Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 2080                2.7          50.9615                 1.82           96
# 202                 4.1         163.8720                 9.79           99
# 1530                4.0         100.8610                 8.49           82
# 2127                5.7          89.2395                 4.65           99
# 1715                6.3         114.3280                 7.20           94
#
#       Measles   BMI  ...  Diphtheria  Incidents_HIV  GDP_per_capita  \
# 2080       90  23.6  ...          96           0.07           55647
# 202        99  26.6  ...          99           0.22            5967
# 1530       94  26.5  ...          89           0.03            6517
# 2127       99  25.6  ...          99           0.16            7694
# 1715       86  26.0  ...          95           0.02            5589
#
#       Population_mln  Thinness_ten_nineteen_years  Thinness_five_nine_years  \
# 2080            5.54                          2.2                       2.2
# 202             9.46                          1.9                       2.0
# 1530            0.62                          1.8                       1.8
# 2127           11.32                          3.5                       3.3
# 1715            7.10                          2.0                       2.0
#
#       Schooling  Economy_status_Developed  Economy_status_Developing  \
# 2080       11.5                         0                          1
# 202        12.2                         0                          1
# 1530       11.3                         0                          1
# 2127       11.4                         0                          1
# 1715       11.0                         0                          1
#
#       Life_expectancy
# 2080             82.7
# 202              73.6
# 1530             76.4
# 2127             78.6
# 1715             75.3
#
# [5 rows x 21 columns]

# %%
# check for na's
life_expectancy.isna()
# Out:
#       Country  Region   Year  Infant_deaths  Under_five_deaths  \
# 0       False   False  False          False              False
# 1       False   False  False          False              False
# 2       False   False  False          False              False
# 3       False   False  False          False              False
# 4       False   False  False          False              False
# ...       ...     ...    ...            ...                ...
# 2859    False   False  False          False              False
# 2860    False   False  False          False              False
# 2861    False   False  False          False              False
# 2862    False   False  False          False              False
# 2863    False   False  False          False              False
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles    BMI  ...  \
# 0               False                False        False    False  False  ...
# 1               False                False        False    False  False  ...
# 2               False                False        False    False  False  ...
# 3               False                False        False    False  False  ...
# 4               False                False        False    False  False  ...
# ...               ...                  ...          ...      ...    ...  ...
# 2859            False                False        False    False  False  ...
# 2860            False                False        False    False  False  ...
# 2861            False                False        False    False  False  ...
# 2862            False                False        False    False  False  ...
# 2863            False                False        False    False  False  ...
#
#       Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0          False          False           False           False
# 1          False          False           False           False
# 2          False          False           False           False
# 3          False          False           False           False
# 4          False          False           False           False
# ...          ...            ...             ...             ...
# 2859       False          False           False           False
# 2860       False          False           False           False
# 2861       False          False           False           False
# 2862       False          False           False           False
# 2863       False          False           False           False
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                           False                     False      False
# 1                           False                     False      False
# 2                           False                     False      False
# 3                           False                     False      False
# 4                           False                     False      False
# ...                           ...                       ...        ...
# 2859                        False                     False      False
# 2860                        False                     False      False
# 2861                        False                     False      False
# 2862                        False                     False      False
# 2863                        False                     False      False
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 0                        False                      False            False
# 1                        False                      False            False
# 2                        False                      False            False
# 3                        False                      False            False
# 4                        False                      False            False
# ...                        ...                        ...              ...
# 2859                     False                      False            False
# 2860                     False                      False            False
# 2861                     False                      False            False
# 2862                     False                      False            False
# 2863                     False                      False            False
#
# [2864 rows x 21 columns]

# %%
# check for duplicates
duplicate_countries = life_expectancy[life_expectancy.duplicated(subset=['Country','Year'],keep=False)==True]
duplicate_countries['Country'].unique()
# Out:
# array([], dtype=object)

# %%
# Summary Statistics -- add in other columns of interest -- figure out how to round numbers
# dataset includes 179 countries, data from 16 years (2000-2015)

sum_stats = life_expectancy[['Infant_deaths', 'Under_five_deaths',
       'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles',
       'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita',
       'Population_mln', 'Schooling', 'Life_expectancy']].describe()
sum_stats.rename(columns={'Infant_deaths':'Infant Deaths', 'Under_five_deaths':'Under Five Deaths',
                          'Adult_mortality':'Adult Mortality', 'Alcohol_consumption':'Alcohol Consumption', 
                          'Hepatitis_B':'Hepatitis B', 'Incidents_HIV':'Incidents HIV', 
                          'GDP_per_capita':'GDP per capita','Population_mln':'Population (Millions)',
                          'Schooling':'Years of Schooling', 'Life_expectancy':'Life Expectancy'},inplace=True)
sum_stats = sum_stats.round(2)
sum_stats
# Out:
#        Infant Deaths  Under Five Deaths  Adult Mortality  Alcohol Consumption  \
# count        2864.00            2864.00          2864.00              2864.00
# mean           30.36              42.94           192.25                 4.82
# std            27.54              44.57           114.91                 3.98
# min             1.80               2.30            49.38                 0.00
# 25%             8.10               9.67           106.91                 1.20
# 50%            19.60              23.10           163.84                 4.02
# 75%            47.35              66.00           246.79                 7.78
# max           138.10             224.90           719.36                17.87
#
#        Hepatitis B  Measles      BMI    Polio  Diphtheria  Incidents HIV  \
# count      2864.00  2864.00  2864.00  2864.00     2864.00        2864.00
# mean         84.29    77.34    25.03    86.50       86.27           0.89
# std          16.00    18.66     2.19    15.08       15.53           2.38
# min          12.00    10.00    19.80     8.00       16.00           0.01
# 25%          78.00    64.00    23.20    81.00       81.00           0.08
# 50%          89.00    83.00    25.50    93.00       93.00           0.15
# 75%          96.00    93.00    26.40    97.00       97.00           0.46
# max          99.00    99.00    32.10    99.00       99.00          21.68
#
#        GDP per capita  Population (Millions)  Years of Schooling  \
# count         2864.00                2864.00             2864.00
# mean         11540.92                  36.68                7.63
# std          16934.79                 136.49                3.17
# min            148.00                   0.08                1.10
# 25%           1415.75                   2.10                5.10
# 50%           4217.00                   7.85                7.80
# 75%          12557.00                  23.69               10.30
# max         112418.00                1379.86               14.10
#
#        Life Expectancy
# count          2864.00
# mean             68.86
# std               9.41
# min              39.40
# 25%              62.70
# 50%              71.40
# 75%              75.40
# max              83.80

# %%
developed_plot = developed.groupby('Region').nunique().reset_index()
developed_plot
# Out:
#            Region  Country  Year  Infant_deaths  Under_five_deaths  \
# 0            Asia        1    16             13                 15
# 1  European Union       27    16             93                104
# 2     Middle East        1    16             15                 16
# 3   North America        2    16             20                 24
# 4         Oceania        2    16             24                 26
# 5  Rest of Europe        4    16             38                 40
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles  BMI  ...  \
# 0               16                   16            1        9    3  ...
# 1              432                  328           43       45   27  ...
# 2               16                   14            4        9   12  ...
# 3               32                   20           13        4   20  ...
# 4               32                   29            9       11   19  ...
# 5               64                   59            1       13   22  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0           6              1              16              15
# 1          22             28             430             348
# 2           6              1              16              16
# 3           9              3              32              32
# 4           7              4              32              32
# 5          11              9              64              54
#
#    Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                            6                         5         13
# 1                           35                        41         68
# 2                            2                         1         10
# 3                            4                         4         17
# 4                            4                         3         13
# 5                            7                         6         33
#
#    Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 0                         1                          1               15
# 1                         1                          1              121
# 2                         1                          1               14
# 3                         1                          1               28
# 4                         1                          1               26
# 5                         1                          1               42
#
# [6 rows x 21 columns]

# %%
gdp_bins = [0, 1416, 4218, 12558, 112418]

labels = ["<$1416", "$1416-$4218", "$4218-12558", "$12558-$112418"]
developed["GDP Ranges"] = pd.cut(developed['GDP_per_capita'],gdp_bins,labels=labels)
developed.groupby('GDP Ranges').mean().reset_index(inplace=True)
developed
# Out:
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/2642984733.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed["GDP Ranges"] = pd.cut(developed['GDP_per_capita'],gdp_bins,labels=labels)
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/2642984733.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   developed.groupby('GDP Ranges').mean().reset_index(inplace=True)
#           Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 1           Spain  European Union  2015            2.7                3.3
# 4          Israel     Middle East  2012            3.4                4.3
# 7         Hungary  European Union  2000            8.7               10.1
# 11          Malta  European Union  2007            6.0                6.8
# 14    Switzerland  Rest of Europe  2006            4.2                4.9
# ...           ...             ...   ...            ...                ...
# 2850      Belgium  European Union  2009            3.7                4.5
# 2855      Finland  European Union  2001            3.4                4.2
# 2856        Japan            Asia  2014            2.1                2.8
# 2862    Lithuania  European Union  2002            7.9                9.9
# 2863      Iceland  Rest of Europe  2011            2.1                2.6
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 1             57.9025                10.35           97       94  26.0  ...
# 4             57.9510                 2.89           97       89  27.0  ...
# 7            192.9690                12.23           88       99  25.9  ...
# 11            58.0185                 7.47           82       77  27.1  ...
# 14            63.2435                10.24           88       71  25.0  ...
# ...               ...                  ...          ...      ...   ...  ...
# 2850          84.1680                10.10           97       83  25.9  ...
# 2855          98.8365                 8.94           88       92  25.8  ...
# 2856          55.5820                 8.40           83       94  22.7  ...
# 2862         204.0120                11.00           94       95  26.1  ...
# 2863          50.5745                 6.84           88       90  26.1  ...
#
#       Incidents_HIV  GDP_per_capita  Population_mln  \
# 1              0.09           25742           46.44
# 4              0.08           33995            7.91
# 7              0.08            8971           10.21
# 11             0.08           19338            0.41
# 14             0.08           79368            7.48
# ...             ...             ...             ...
# 2850           0.08           39025           10.80
# 2855           0.08           38785            5.19
# 2856           0.17           34387          127.28
# 2862           0.05            7424            3.44
# 2863           0.05           48934            0.32
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 1                             0.6                       0.5        9.7
# 4                             1.2                       1.1       12.8
# 7                             2.3                       2.3       10.2
# 11                            0.7                       0.7        9.9
# 14                            0.6                       0.4       12.3
# ...                           ...                       ...        ...
# 2850                          0.9                       0.9       11.1
# 2855                          0.9                       0.8        9.4
# 2856                          2.0                       1.7       12.5
# 2862                          3.3                       3.3       11.1
# 2863                          0.9                       0.9       11.0
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 1                            1                          0             82.8
# 4                            1                          0             81.7
# 7                            1                          0             71.2
# 11                           1                          0             79.8
# 14                           1                          0             81.5
# ...                        ...                        ...              ...
# 2850                         1                          0             80.0
# 2855                         1                          0             78.0
# 2856                         1                          0             83.6
# 2862                         1                          0             71.8
# 2863                         1                          0             82.4
#
#           GDP Ranges
# 1     $12558-$112418
# 4     $12558-$112418
# 7        $4218-12558
# 11    $12558-$112418
# 14    $12558-$112418
# ...              ...
# 2850  $12558-$112418
# 2855  $12558-$112418
# 2856  $12558-$112418
# 2862     $4218-12558
# 2863  $12558-$112418
#
# [592 rows x 22 columns]

# %%
developing["GDP Ranges"] = pd.cut(developing['GDP_per_capita'],gdp_bins,labels=labels)
developing.groupby('GDP Ranges').mean().reset_index(inplace=True)
developing
# Out:
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/1163784308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developing["GDP Ranges"] = pd.cut(developing['GDP_per_capita'],gdp_bins,labels=labels)
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/1163784308.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   developing.groupby('GDP Ranges').mean().reset_index(inplace=True)
#                  Country                         Region  Year  Infant_deaths  \
# 0                Turkiye                    Middle East  2015           11.1
# 2                  India                           Asia  2007           51.5
# 3                 Guyana                  South America  2006           32.8
# 5             Costa Rica  Central America and Caribbean  2006            9.8
# 6     Russian Federation                 Rest of Europe  2015            6.6
# ...                  ...                            ...   ...            ...
# 2857             Belarus                 Rest of Europe  2000            9.9
# 2858  Iran, Islamic Rep.                    Middle East  2007           19.7
# 2859               Niger                         Africa  2000           97.0
# 2860            Mongolia                           Asia  2009           23.9
# 2861           Sri Lanka                           Asia  2004           17.7
#
#       Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 0                  13.0         105.8240                1.320           97
# 2                  67.9         201.0765                1.570           60
# 3                  40.5         222.1965                5.680           93
# 5                  11.2          95.2200                4.190           88
# 6                   8.2         223.0000                8.060           97
# ...                 ...              ...                  ...          ...
# 2857               12.7         239.7160               12.920           70
# 2858               23.1         129.9335                0.023           97
# 2859              224.9         291.8240                0.092           72
# 2860               28.6         235.2330                6.560           97
# 2861               28.9         134.8950                1.560           62
#
#       Measles   BMI  ...  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0          65  27.8  ...           0.08           11006           78.53
# 2          35  21.2  ...           0.13            1076         1183.21
# 3          74  25.3  ...           0.79            4146            0.75
# 5          86  26.4  ...           0.16            9110            4.35
# 6          97  26.2  ...           0.08            9313          144.10
# ...       ...   ...  ...            ...             ...             ...
# 2857       92  25.7  ...           0.05            2617            9.98
# 2858       65  25.6  ...           0.14            5305           71.34
# 2859       64  20.8  ...           0.49             399           11.33
# 2860       97  25.3  ...           0.02            2515            2.67
# 2861       95  21.9  ...           0.02            2130           19.39
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                             4.9                       4.8        7.8
# 2                            27.1                      28.0        5.0
# 3                             5.7                       5.5        7.9
# 5                             2.0                       1.9        7.9
# 6                             2.3                       2.3       12.0
# ...                           ...                       ...        ...
# 2857                          2.7                       2.8        8.9
# 2858                          7.5                       7.8        8.9
# 2859                         12.8                      12.9        1.1
# 2860                          2.2                       2.3        9.1
# 2861                         15.4                      15.5       10.3
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 0                            0                          1             76.5
# 2                            0                          1             65.4
# 3                            0                          1             67.0
# 5                            0                          1             78.2
# 6                            0                          1             71.2
# ...                        ...                        ...              ...
# 2857                         0                          1             68.9
# 2858                         0                          1             72.6
# 2859                         0                          1             49.9
# 2860                         0                          1             66.9
# 2861                         0                          1             74.3
#
#        GDP Ranges
# 0     $4218-12558
# 2          <$1416
# 3     $1416-$4218
# 5     $4218-12558
# 6     $4218-12558
# ...           ...
# 2857  $1416-$4218
# 2858  $4218-12558
# 2859       <$1416
# 2860  $1416-$4218
# 2861  $1416-$4218
#
# [2272 rows x 22 columns]

# %%
twentyfifteen.loc[twentyfifteen['Region']=='Rest of Europe']
# Out:
#                      Country          Region  Year  Infant_deaths  \
# 6         Russian Federation  Rest of Europe  2015            6.6
# 110                   Norway  Rest of Europe  2015            2.2
# 202                  Belarus  Rest of Europe  2015            3.1
# 219                  Ukraine  Rest of Europe  2015            8.1
# 626                  Albania  Rest of Europe  2015            8.5
# 1204         North Macedonia  Rest of Europe  2015           10.0
# 1319                 Moldova  Rest of Europe  2015           13.6
# 1530              Montenegro  Rest of Europe  2015            3.3
# 1613             Switzerland  Rest of Europe  2015            3.7
# 1715                  Serbia  Rest of Europe  2015            5.4
# 1784  Bosnia and Herzegovina  Rest of Europe  2015            5.4
# 1809          United Kingdom  Rest of Europe  2015            3.8
# 1823                 Armenia  Rest of Europe  2015           12.6
# 2290                 Georgia  Rest of Europe  2015            9.4
# 2442                 Iceland  Rest of Europe  2015            1.8
#
#       Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 6                   8.2         223.0000                 8.06           97
# 110                 2.7          53.8970                 5.97           88
# 202                 4.1         163.8720                 9.79           99
# 219                 9.5         202.8000                 6.04           22
# 626                 9.6          75.2050                 4.33           99
# 1204               11.4          97.1970                 3.57           92
# 1319               15.8         171.2775                 6.76           88
# 1530                4.0         100.8610                 8.49           82
# 1613                4.3          49.3840                 9.62           88
# 1715                6.3         114.3280                 7.20           94
# 1784                6.3          96.0670                 4.90           82
# 1809                4.5          69.3335                 9.59           88
# 1823               14.1         125.4875                 4.04           94
# 2290               10.5         156.2355                 6.95           94
# 2442                2.3          55.3590                 7.66           88
#
#       Measles   BMI  ...  Incidents_HIV  GDP_per_capita  Population_mln  \
# 6          97  26.2  ...           0.08            9313          144.10
# 110        91  26.6  ...           0.04           74356            5.19
# 202        99  26.6  ...           0.22            5967            9.46
# 219        57  26.5  ...           0.23            2125           45.15
# 626        98  26.6  ...           0.03            3953            2.88
# 1204       97  26.7  ...           0.08            4862            2.07
# 1319       92  27.0  ...           0.36            2732            2.83
# 1530       94  26.5  ...           0.03            6517            0.62
# 1613       87  25.2  ...           0.05           84776            8.28
# 1715       86  26.0  ...           0.02            5589            7.10
# 1784       88  25.7  ...           0.08            4730            3.43
# 1809       86  27.1  ...           0.08           45405           65.12
# 1823       97  26.3  ...           0.09            3607            2.93
# 2290       91  27.5  ...           0.14            4014            3.73
# 2442       94  26.2  ...           0.05           52952            0.33
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 6                             2.3                       2.3       12.0
# 110                           0.8                       0.7       12.5
# 202                           1.9                       2.0       12.2
# 219                           2.3                       2.4       11.3
# 626                           1.2                       1.3        9.7
# 1204                          2.1                       2.1        9.6
# 1319                          2.7                       2.8       11.6
# 1530                          1.8                       1.8       11.3
# 1613                          0.4                       0.3       13.4
# 1715                          2.0                       2.0       11.0
# 1784                          2.3                       2.3        9.0
# 1809                          0.8                       0.6       12.8
# 1823                          2.1                       2.2       11.6
# 2290                          2.7                       2.8       12.7
# 2442                          1.0                       0.9       12.2
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 6                            0                          1             71.2
# 110                          1                          0             82.3
# 202                          0                          1             73.6
# 219                          0                          1             71.2
# 626                          0                          1             78.0
# 1204                         0                          1             75.4
# 1319                         0                          1             71.5
# 1530                         0                          1             76.4
# 1613                         1                          0             82.9
# 1715                         0                          1             75.3
# 1784                         0                          1             76.9
# 1809                         1                          0             81.0
# 1823                         0                          1             74.5
# 2290                         0                          1             73.0
# 2442                         1                          0             82.5
#
#           GDP Ranges
# 6        $4218-12558
# 110   $12558-$112418
# 202      $4218-12558
# 219      $1416-$4218
# 626      $1416-$4218
# 1204     $4218-12558
# 1319     $1416-$4218
# 1530     $4218-12558
# 1613  $12558-$112418
# 1715     $4218-12558
# 1784     $4218-12558
# 1809  $12558-$112418
# 1823     $1416-$4218
# 2290     $1416-$4218
# 2442  $12558-$112418
#
# [15 rows x 22 columns]

# %%
life_expectancy["GDP Ranges"] = pd.cut(life_expectancy['GDP_per_capita'],gdp_bins,labels=labels)

# %%
grouped_dev = developed.groupby("GDP Ranges").mean().reset_index()
grouped_undev = developing.groupby("GDP Ranges").mean().reset_index()
le_merge = pd.DataFrame({'GDP Ranges':grouped_dev["GDP Ranges"],
                        'Developed LE':grouped_dev["Life_expectancy"],
                        'Developing LE':grouped_undev['Life_expectancy']})

le_merge
# Out:
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/2128141066.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_dev = developed.groupby("GDP Ranges").mean().reset_index()
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/2128141066.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_undev = developing.groupby("GDP Ranges").mean().reset_index()
#        GDP Ranges  Developed LE  Developing LE
# 0          <$1416           NaN      58.140167
# 1     $1416-$4218     71.750000      67.354062
# 2     $4218-12558     73.592727      71.657521
# 3  $12558-$112418     79.659792      74.569068

# %%
plt.bar(le_merge['GDP Ranges'],le_merge['Developed LE'])
plt.bar(le_merge['GDP Ranges'],le_merge['Developing LE'])

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
developed.describe()
# developing.describe()
# 8.850451
# Out:
#               Year  Infant_deaths  Under_five_deaths  Adult_mortality  \
# count   592.000000     592.000000         592.000000       592.000000
# mean   2007.500000       4.696115           5.649831        95.610448
# std       4.613671       2.343729           2.762573        40.871055
# min    2000.000000       1.800000           2.300000        49.384000
# 25%    2003.750000       3.300000           4.000000        67.326625
# 50%    2007.500000       4.100000           4.900000        80.192250
# 75%    2011.250000       5.400000           6.425000       111.041125
# max    2015.000000      18.100000          21.600000       237.838500
#
#        Alcohol_consumption  Hepatitis_B     Measles         BMI       Polio  \
# count           592.000000   592.000000  592.000000  592.000000  592.000000
# mean             10.049358    87.849662   88.261824   26.078378   94.866554
# std               2.497904    14.528671   10.046796    0.927985    4.022453
# min               2.300000    14.000000   31.000000   22.500000   71.000000
# 25%               8.582500    88.000000   86.000000   25.600000   93.000000
# 50%              10.215000    91.000000   91.000000   26.100000   96.000000
# 75%              11.572500    96.000000   95.000000   26.700000   98.000000
# max              17.870000    99.000000   99.000000   28.800000   99.000000
#
#        Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# count  592.000000     592.000000      592.000000      592.000000
# mean    95.077703       0.075051    33683.547297       27.238514
# std      3.823170       0.043548    21321.497749       53.333421
# min     72.000000       0.010000     3718.000000        0.280000
# 25%     93.000000       0.040000    16465.000000        4.277500
# 50%     96.000000       0.080000    33545.000000        8.330000
# 75%     98.000000       0.080000    44403.250000       22.512500
# max     99.000000       0.290000   112418.000000      320.740000
#
#        Thinness_ten_nineteen_years  Thinness_five_nine_years   Schooling  \
# count                   592.000000                592.000000  592.000000
# mean                      1.248649                  1.222635   11.355912
# std                       0.729646                  0.801455    1.305085
# min                       0.300000                  0.200000    6.800000
# 25%                       0.700000                  0.600000   10.500000
# 50%                       1.000000                  0.900000   11.700000
# 75%                       1.800000                  1.800000   12.300000
# max                       4.000000                  4.300000   14.100000
#
#        Economy_status_Developed  Economy_status_Developing  Life_expectancy
# count                     592.0                      592.0       592.000000
# mean                        1.0                        0.0        78.505743
# std                         0.0                        0.0         3.159564
# min                         1.0                        0.0        70.300000
# 25%                         1.0                        0.0        76.800000
# 50%                         1.0                        0.0        79.300000
# 75%                         1.0                        0.0        80.900000
# max                         1.0                        0.0        83.800000

# %%
# LIFE EXPECTANCY BY REGION (T-TEST)
le_developed_mean = life_expectancy.query('Economy_status_Developed==1')['Life_expectancy'].mean()
print(le_developed_mean)
le_developing_mean = life_expectancy.query('Economy_status_Developed==0')['Life_expectancy'].mean()
print(le_developing_mean)

stats.ttest_ind(life_expectancy.query('Economy_status_Developed==1')['Life_expectancy'],
                life_expectancy.query('Economy_status_Developed==0')['Life_expectancy'],equal_var=False)
# Out:
# 78.50574324324323
# 66.34172535211268
# Ttest_indResult(statistic=53.68486022748816, pvalue=0.0)

# %%
# LIFE EXPECTANCY BY REGION (T-TEST)
gdp_developed_mean = life_expectancy.query('Economy_status_Developed==1')['GDP_per_capita'].mean()
print(developed_mean)
gdp_undeveloped_mean = life_expectancy.query('Economy_status_Developed==0')['GDP_per_capita'].mean()
print(developing_mean)

stats.ttest_ind(life_expectancy.query('Economy_status_Developed==1')['GDP_per_capita'],
                life_expectancy.query('Economy_status_Developed==0')['GDP_per_capita'],equal_var=False)
# Out:
# 33683.5472972973
# 5771.368397887324
# Ttest_indResult(statistic=31.127797009853566, pvalue=9.317764506610166e-131)

# %%
# LIFE EXPECTANCY vs. GDP RANGES (ANOVA)
life_expectancy.boxplot('Life_expectancy', by = 'GDP Ranges', figsize=(20,10))
plt.show()

# Extract individual groups
group0 = life_expectancy[life_expectancy['GDP Ranges']=="<$1416"]['Life_expectancy']
group1 = life_expectancy[life_expectancy['GDP Ranges']=="$1416-$4218"]['Life_expectancy']
group2 = life_expectancy[life_expectancy['GDP Ranges']=="$4218-12558"]['Life_expectancy']
group3 = life_expectancy[life_expectancy['GDP Ranges']=="$12558-$112418"]['Life_expectancy']

# ANOVA Test
print(stats.f_oneway(group1,group2,group3))
# Out:
# F_onewayResult(statistic=625.4755890129329, pvalue=1.045725475514985e-214)

# %%
# By country, in 2015? 
twentyfifteen = life_expectancy.query('Year==2015')
twentyfifteen_region = twentyfifteen.groupby('Region').mean().reset_index()
# Out:
# /var/folders/tf/jtj87yg57613h56rlkc7jv0w0000gn/T/ipykernel_11014/3079361763.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   twentyfifteen_region = twentyfifteen.groupby('Region').mean().reset_index()

# %%
twentyfifteen.boxplot('Life_expectancy', by = 'Region', figsize=(20,10))
plt.show()

# Extract individual groups
africa = twentyfifteen[twentyfifteen['Region']=="Africa"]['Life_expectancy']
asia = twentyfifteen[twentyfifteen['Region']=="Asia"]['Life_expectancy']
cacaribbean = twentyfifteen[twentyfifteen['Region']=="Central America and Caribbean"]['Life_expectancy']
europeanunion = twentyfifteen[twentyfifteen['Region']=="European Union"]['Life_expectancy']
middleeast = twentyfifteen[twentyfifteen['Region']=="Middle East"]['Life_expectancy']
northamerica = twentyfifteen[twentyfifteen['Region']=="North America"]['Life_expectancy']
oceania = twentyfifteen[twentyfifteen['Region']=="Oceania"]['Life_expectancy']
restofeurope = twentyfifteen[twentyfifteen['Region']=="Rest of Europe"]['Life_expectancy']
southamerica = twentyfifteen[twentyfifteen['Region']=="South America"]['Life_expectancy']

# ANOVA Test under 75 vs over 
print(stats.f_oneway(africa,oceania,asia,cacaribbean))
print(stats.f_oneway(europeanunion,middleeast,northamerica,southamerica,restofeurope))

# T-test (lowest/highest,lowest/second lowest, highest/second highest)
print(stats.ttest_ind(africa,europeanunion,equal_var=False))
print()
# Out:
# F_onewayResult(statistic=29.12907375646511, pvalue=9.427455249816252e-14)
# F_onewayResult(statistic=6.084491177201229, pvalue=0.0003136531814695706)
# Ttest_indResult(statistic=-16.210284856011086, pvalue=4.1670091577619766e-26)

# %%
twentyfifteen_region['Life_expectancy'].mean()
# Out:
# 73.74065236041844

# %%
# Set up expected values for expected life expectancy values
twentyfifteen_region['Expected LE']=[73.7406523604184,73.7406523604184,73.7406523604184,73.7406523604184,73.7406523604184,
                                    73.7406523604184,73.7406523604184,73.7406523604184,73.7406523604184]
print(twentyfifteen_region['Expected LE'].sum())
print(twentyfifteen_region['Life_expectancy'].sum())
# Out:
# 663.6658712437655
# 663.665871243766

# %%
# CHI SQUARE: LIFE EXPECTANCY BY REGION IN 2015 
stats.chisquare(twentyfifteen_region['Life_expectancy'],twentyfifteen_region['Expected LE'])
# Out:
# Power_divergenceResult(statistic=2.7475816130544928, pvalue=0.9491862036856972)
