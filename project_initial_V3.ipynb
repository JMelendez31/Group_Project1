# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
life_expectancy = pd.read_csv('Life-Expectancy-Data-Updated.csv')
life_expectancy
# Out:
#         Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0       Turkiye     Middle East  2015           11.1               13.0
# 1         Spain  European Union  2015            2.7                3.3
# 2         India            Asia  2007           51.5               67.9
# 3        Guyana   South America  2006           32.8               40.5
# 4        Israel     Middle East  2012            3.4                4.3
# ...         ...             ...   ...            ...                ...
# 2859      Niger          Africa  2000           97.0              224.9
# 2860   Mongolia            Asia  2009           23.9               28.6
# 2861  Sri Lanka            Asia  2004           17.7               28.9
# 2862  Lithuania  European Union  2002            7.9                9.9
# 2863    Iceland  Rest of Europe  2011            2.1                2.6
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0            105.8240                1.320           97       65  27.8  ...
# 1             57.9025               10.350           97       94  26.0  ...
# 2            201.0765                1.570           60       35  21.2  ...
# 3            222.1965                5.680           93       74  25.3  ...
# 4             57.9510                2.890           97       89  27.0  ...
# ...               ...                  ...          ...      ...   ...  ...
# 2859         291.8240                0.092           72       64  20.8  ...
# 2860         235.2330                6.560           97       97  25.3  ...
# 2861         134.8950                1.560           62       95  21.9  ...
# 2862         204.0120               11.000           94       95  26.1  ...
# 2863          50.5745                6.840           88       90  26.1  ...
#
#       Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0             97           0.08           11006           78.53
# 1             97           0.09           25742           46.44
# 2             64           0.13            1076         1183.21
# 3             93           0.79            4146            0.75
# 4             94           0.08           33995            7.91
# ...          ...            ...             ...             ...
# 2859          34           0.49             399           11.33
# 2860          95           0.02            2515            2.67
# 2861          97           0.02            2130           19.39
# 2862          95           0.05            7424            3.44
# 2863          95           0.05           48934            0.32
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                             4.9                       4.8        7.8
# 1                             0.6                       0.5        9.7
# 2                            27.1                      28.0        5.0
# 3                             5.7                       5.5        7.9
# 4                             1.2                       1.1       12.8
# ...                           ...                       ...        ...
# 2859                         12.8                      12.9        1.1
# 2860                          2.2                       2.3        9.1
# 2861                         15.4                      15.5       10.3
# 2862                          3.3                       3.3       11.1
# 2863                          0.9                       0.9       11.0
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 0                            0                          1             76.5
# 1                            1                          0             82.8
# 2                            0                          1             65.4
# 3                            0                          1             67.0
# 4                            1                          0             81.7
# ...                        ...                        ...              ...
# 2859                         0                          1             49.9
# 2860                         0                          1             66.9
# 2861                         0                          1             74.3
# 2862                         1                          0             71.8
# 2863                         1                          0             82.4
#
# [2864 rows x 21 columns]

# %%
size_bins = [0, 5000, 10000, 25000, 50000, 75000, 115000]
category_labels = ["<$5,000", "$5,000-$10,000", "$10,000-$25,000","$25,000-$50,000","$50,000-$75,000","$75,000-$115,000"]

life_expectancy["GDP Ranges"] = pd.cut(life_expectancy["GDP_per_capita"],
                                                             size_bins, labels = category_labels)
life_expectancy
# Out:
#         Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0       Turkiye     Middle East  2015           11.1               13.0
# 1         Spain  European Union  2015            2.7                3.3
# 2         India            Asia  2007           51.5               67.9
# 3        Guyana   South America  2006           32.8               40.5
# 4        Israel     Middle East  2012            3.4                4.3
# ...         ...             ...   ...            ...                ...
# 2859      Niger          Africa  2000           97.0              224.9
# 2860   Mongolia            Asia  2009           23.9               28.6
# 2861  Sri Lanka            Asia  2004           17.7               28.9
# 2862  Lithuania  European Union  2002            7.9                9.9
# 2863    Iceland  Rest of Europe  2011            2.1                2.6
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0            105.8240                1.320           97       65  27.8  ...
# 1             57.9025               10.350           97       94  26.0  ...
# 2            201.0765                1.570           60       35  21.2  ...
# 3            222.1965                5.680           93       74  25.3  ...
# 4             57.9510                2.890           97       89  27.0  ...
# ...               ...                  ...          ...      ...   ...  ...
# 2859         291.8240                0.092           72       64  20.8  ...
# 2860         235.2330                6.560           97       97  25.3  ...
# 2861         134.8950                1.560           62       95  21.9  ...
# 2862         204.0120               11.000           94       95  26.1  ...
# 2863          50.5745                6.840           88       90  26.1  ...
#
#       Incidents_HIV  GDP_per_capita  Population_mln  \
# 0              0.08           11006           78.53
# 1              0.09           25742           46.44
# 2              0.13            1076         1183.21
# 3              0.79            4146            0.75
# 4              0.08           33995            7.91
# ...             ...             ...             ...
# 2859           0.49             399           11.33
# 2860           0.02            2515            2.67
# 2861           0.02            2130           19.39
# 2862           0.05            7424            3.44
# 2863           0.05           48934            0.32
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                             4.9                       4.8        7.8
# 1                             0.6                       0.5        9.7
# 2                            27.1                      28.0        5.0
# 3                             5.7                       5.5        7.9
# 4                             1.2                       1.1       12.8
# ...                           ...                       ...        ...
# 2859                         12.8                      12.9        1.1
# 2860                          2.2                       2.3        9.1
# 2861                         15.4                      15.5       10.3
# 2862                          3.3                       3.3       11.1
# 2863                          0.9                       0.9       11.0
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 0                            0                          1             76.5
# 1                            1                          0             82.8
# 2                            0                          1             65.4
# 3                            0                          1             67.0
# 4                            1                          0             81.7
# ...                        ...                        ...              ...
# 2859                         0                          1             49.9
# 2860                         0                          1             66.9
# 2861                         0                          1             74.3
# 2862                         1                          0             71.8
# 2863                         1                          0             82.4
#
#            GDP Ranges
# 0     $10,000-$25,000
# 1     $25,000-$50,000
# 2             <$5,000
# 3             <$5,000
# 4     $25,000-$50,000
# ...               ...
# 2859          <$5,000
# 2860          <$5,000
# 2861          <$5,000
# 2862   $5,000-$10,000
# 2863  $25,000-$50,000
#
# [2864 rows x 22 columns]

# %%
gdp_ranges_df=life_expectancy.groupby(["GDP Ranges", "Economy_status_Developed"])["Life_expectancy"].mean().reset_index()

# %%
# General sample info
countries = life_expectancy['Country'].unique()
years = life_expectancy['Year'].unique()
print(len(countries))
print(len(years))
# Out:
# 179
# 16

# %%
columns = life_expectancy.columns
columns
# Out:
# Index(['Country', 'Region', 'Year', 'Infant_deaths', 'Under_five_deaths',
#        'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles',
#        'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita',
#        'Population_mln', 'Thinness_ten_nineteen_years',
#        'Thinness_five_nine_years', 'Schooling', 'Economy_status_Developed',
#        'Economy_status_Developing', 'Life_expectancy', 'GDP Ranges'],
#       dtype='object')

# %%
developed = life_expectancy.query('Economy_status_Developed==1')
developed_by_region = developed.groupby('Region').nunique().reset_index()
developed_by_region
# Out:
#            Region  Country  Year  Infant_deaths  Under_five_deaths  \
# 0            Asia        1    16             13                 15
# 1  European Union       27    16             93                104
# 2     Middle East        1    16             15                 16
# 3   North America        2    16             20                 24
# 4         Oceania        2    16             24                 26
# 5  Rest of Europe        4    16             38                 40
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles  BMI  ...  \
# 0               16                   16            1        9    3  ...
# 1              432                  328           43       45   27  ...
# 2               16                   14            4        9   12  ...
# 3               32                   20           13        4   20  ...
# 4               32                   29            9       11   19  ...
# 5               64                   59            1       13   22  ...
#
#    Incidents_HIV  GDP_per_capita  Population_mln  Thinness_ten_nineteen_years  \
# 0              1              16              15                            6
# 1             28             430             348                           35
# 2              1              16              16                            2
# 3              3              32              32                            4
# 4              4              32              32                            4
# 5              9              64              54                            7
#
#    Thinness_five_nine_years  Schooling  Economy_status_Developed  \
# 0                         5         13                         1
# 1                        41         68                         1
# 2                         1         10                         1
# 3                         4         17                         1
# 4                         3         13                         1
# 5                         6         33                         1
#
#    Economy_status_Developing  Life_expectancy  GDP Ranges
# 0                          1               15           1
# 1                          1              121           6
# 2                          1               14           1
# 3                          1               28           2
# 4                          1               26           2
# 5                          1               42           3
#
# [6 rows x 22 columns]

# %%
undeveloped = life_expectancy.query('Economy_status_Developing == 1')
undeveloped_by_region = undeveloped.groupby('Region').nunique().reset_index()
undeveloped_by_region
# Out:
#                           Region  Country  Year  Infant_deaths  \
# 0                         Africa       51    16            558
# 1                           Asia       26    16            299
# 2  Central America and Caribbean       19    16            194
# 3                    Middle East       13    16            138
# 4                  North America        1    16             16
# 5                        Oceania        9    16            113
# 6                 Rest of Europe       11    16            112
# 7                  South America       12    16            149
#
#    Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 0                620              816                  467           67
# 1                319              411                  292           58
# 2                216              304                  257           33
# 3                145              208                  130           41
# 4                 16               16                   15            7
# 5                121              144                  109           48
# 6                123              174                  158           40
# 7                155              192                  172           34
#
#    Measles  BMI  ...  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0       57   95  ...            382             705             681
# 1       79   72  ...             51             405             391
# 2       40   61  ...             96             303             188
# 3       46   63  ...             14             207             201
# 4       11   13  ...              2              16              16
# 5       33   81  ...             23             140              70
# 6       30   27  ...             40             175             116
# 7       47   34  ...             41             190             168
#
#    Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                          111                       111         88
# 1                          166                       172         94
# 2                           53                        55         80
# 3                           47                        49         71
# 4                            6                         5         10
# 5                           26                        25         69
# 6                           25                        25         54
# 7                           33                        33         45
#
#    Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 0                         1                          1              282
# 1                         1                          1              179
# 2                         1                          1              135
# 3                         1                          1              104
# 4                         1                          1                7
# 5                         1                          1               96
# 6                         1                          1               93
# 7                         1                          1              106
#
#    GDP Ranges
# 0           3
# 1           5
# 2           4
# 3           5
# 4           1
# 5           2
# 6           2
# 7           3
#
# [8 rows x 22 columns]

# %%
# check for na's
life_expectancy.isna()
# Out:
#       Country  Region   Year  Infant_deaths  Under_five_deaths  \
# 0       False   False  False          False              False
# 1       False   False  False          False              False
# 2       False   False  False          False              False
# 3       False   False  False          False              False
# 4       False   False  False          False              False
# ...       ...     ...    ...            ...                ...
# 2859    False   False  False          False              False
# 2860    False   False  False          False              False
# 2861    False   False  False          False              False
# 2862    False   False  False          False              False
# 2863    False   False  False          False              False
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles    BMI  ...  \
# 0               False                False        False    False  False  ...
# 1               False                False        False    False  False  ...
# 2               False                False        False    False  False  ...
# 3               False                False        False    False  False  ...
# 4               False                False        False    False  False  ...
# ...               ...                  ...          ...      ...    ...  ...
# 2859            False                False        False    False  False  ...
# 2860            False                False        False    False  False  ...
# 2861            False                False        False    False  False  ...
# 2862            False                False        False    False  False  ...
# 2863            False                False        False    False  False  ...
#
#       Incidents_HIV  GDP_per_capita  Population_mln  \
# 0             False           False           False
# 1             False           False           False
# 2             False           False           False
# 3             False           False           False
# 4             False           False           False
# ...             ...             ...             ...
# 2859          False           False           False
# 2860          False           False           False
# 2861          False           False           False
# 2862          False           False           False
# 2863          False           False           False
#
#       Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                           False                     False      False
# 1                           False                     False      False
# 2                           False                     False      False
# 3                           False                     False      False
# 4                           False                     False      False
# ...                           ...                       ...        ...
# 2859                        False                     False      False
# 2860                        False                     False      False
# 2861                        False                     False      False
# 2862                        False                     False      False
# 2863                        False                     False      False
#
#       Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 0                        False                      False            False
# 1                        False                      False            False
# 2                        False                      False            False
# 3                        False                      False            False
# 4                        False                      False            False
# ...                        ...                        ...              ...
# 2859                     False                      False            False
# 2860                     False                      False            False
# 2861                     False                      False            False
# 2862                     False                      False            False
# 2863                     False                      False            False
#
#       GDP Ranges
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 2859       False
# 2860       False
# 2861       False
# 2862       False
# 2863       False
#
# [2864 rows x 22 columns]

# %%
# check for duplicates
duplicate_countries = life_expectancy[life_expectancy.duplicated(subset=['Country','Year'],keep=False)==True]
duplicate_countries['Country'].unique()
# Out:
# array([], dtype=object)

# %%
# Summary Statistics -- add in other columns of interest -- figure out how to round numbers
# dataset includes 179 countries, data from 16 years (2000-2015)

sum_stats = life_expectancy[['Infant_deaths', 'Under_five_deaths',
       'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles',
       'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita',
       'Population_mln', 'Schooling', 'Life_expectancy']].describe()
sum_stats.rename(columns={'Infant_deaths':'Infant Deaths', 'Under_five_deaths':'Under Five Deaths',
                          'Adult_mortality':'Adult Mortality', 'Alcohol_consumption':'Alcohol Consumption', 
                          'Hepatitis_B':'Hepatitis B', 'Incidents_HIV':'Incidents HIV', 
                          'GDP_per_capita':'GDP per capita','Population_mln':'Population (Millions)',
                          'Schooling':'Years of Schooling', 'Life_expectancy':'Life Expectancy'},inplace=True)
sum_stats = sum_stats.round(2)
sum_stats
# Out:
#        Infant Deaths  Under Five Deaths  Adult Mortality  Alcohol Consumption  \
# count        2864.00            2864.00          2864.00              2864.00
# mean           30.36              42.94           192.25                 4.82
# std            27.54              44.57           114.91                 3.98
# min             1.80               2.30            49.38                 0.00
# 25%             8.10               9.67           106.91                 1.20
# 50%            19.60              23.10           163.84                 4.02
# 75%            47.35              66.00           246.79                 7.78
# max           138.10             224.90           719.36                17.87
#
#        Hepatitis B  Measles      BMI    Polio  Diphtheria  Incidents HIV  \
# count      2864.00  2864.00  2864.00  2864.00     2864.00        2864.00
# mean         84.29    77.34    25.03    86.50       86.27           0.89
# std          16.00    18.66     2.19    15.08       15.53           2.38
# min          12.00    10.00    19.80     8.00       16.00           0.01
# 25%          78.00    64.00    23.20    81.00       81.00           0.08
# 50%          89.00    83.00    25.50    93.00       93.00           0.15
# 75%          96.00    93.00    26.40    97.00       97.00           0.46
# max          99.00    99.00    32.10    99.00       99.00          21.68
#
#        GDP per capita  Population (Millions)  Years of Schooling  \
# count         2864.00                2864.00             2864.00
# mean         11540.92                  36.68                7.63
# std          16934.79                 136.49                3.17
# min            148.00                   0.08                1.10
# 25%           1415.75                   2.10                5.10
# 50%           4217.00                   7.85                7.80
# 75%          12557.00                  23.69               10.30
# max         112418.00                1379.86               14.10
#
#        Life Expectancy
# count          2864.00
# mean             68.86
# std               9.41
# min              39.40
# 25%              62.70
# 50%              71.40
# 75%              75.40
# max              83.80

# %%
#Graph for Developed Countries by Region
#Bar Chart

plt.bar(developed_by_region['Region'],developed_by_region['Country'], align="center")
plt.xticks(rotation = 90)
plt.xlabel("Regions")
plt.ylabel("Number of Countries")
plt.title("Number of Developed Countries by Region")
plt.tight_layout()
plt.savefig("../Group_Project1/Fig1.png")
plt.show()

# %%
#Graph for Undeveloped Countries by Region
#Bar Chart

plt.bar(undeveloped_by_region['Region'],undeveloped_by_region['Country'], align="center")
plt.xticks(rotation = 90)
plt.xlabel("Regions")
plt.ylabel("Number of Countries")
plt.title("Number of Undeveloped Countries by Region")
plt.tight_layout()
plt.savefig("../Group_Project1/Fig2.png")
plt.show()

# %%
#scatter plot for GDP per Capita vs Life Expectancy
#compare results to undeveloping and developing
plt.scatter(life_expectancy['Life_expectancy'],life_expectancy['GDP_per_capita'], life_expectancy['Economy_status_Developed'], label = 'Developed Regions')
plt.scatter(life_expectancy['Life_expectancy'],life_expectancy['GDP_per_capita'], life_expectancy['Economy_status_Developing'], label = 'Undeveloped Regions')
plt.xlabel('Life Expectancy')
plt.ylabel('GDP per Capita')
plt.title('Life Expectancy Vs. GDP Per Capita')
plt.legend(loc = 'upper left')
plt.tight_layout()
plt.savefig("../Group_Project1/Fig3.png")
plt.show()

# %%
#range = $0 to $112,418 for Developed Countries
size_bins = [0, 5000, 10000, 25000, 50000, 75000, 115000]
category_labels = ["<$5,000", "$5,000-$10,000", "$10,000-$25,000","$25,000-$50,000","$50,000-$75,000","$75,000-$115,000"]

developed["GDP Ranges"] = pd.cut(developed["GDP_per_capita"],
                                                             size_bins, labels = category_labels)
developed_gdp_ranges = developed.groupby("GDP Ranges").mean(numeric_only = True)
developed_gdp_ranges.reset_index(inplace = True)
developed_gdp_ranges
# Out:
# /var/folders/xl/xk0yxcr97yv5qf0v1jxr20p80000gn/T/ipykernel_94698/839203528.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed["GDP Ranges"] = pd.cut(developed["GDP_per_capita"],
#          GDP Ranges         Year  Infant_deaths  Under_five_deaths  \
# 0           <$5,000  2001.571429      14.442857          17.357143
# 1    $5,000-$10,000  2005.388889       9.272222          11.053704
# 2   $10,000-$25,000  2008.372881       4.623729           5.540678
# 3   $25,000-$50,000  2007.084942       3.867181           4.702317
# 4   $50,000-$75,000  2008.800000       4.023077           4.803077
# 5  $75,000-$115,000  2008.300000       3.226667           3.850000
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B    Measles        BMI  \
# 0       163.055000            10.688571    94.428571  88.571429  25.242857
# 1       162.483398            10.400185    95.907407  94.407407  25.833333
# 2       114.559331            11.090847    92.661017  91.141243  26.383616
# 3        74.636098             9.433012    81.938224  85.625483  25.882239
# 4        77.016023             8.894769    89.753846  87.615385  26.533846
# 5        69.070150            10.946667    90.333333  84.300000  25.620000
#
#        Polio  Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0  95.714286   95.571429       0.028571     4383.714286       12.012857
# 1  95.500000   95.685185       0.060741     7783.833333       14.250370
# 2  95.661017   95.875706       0.079774    16377.564972        7.982994
# 3  94.447876   94.617761       0.079228    38694.864865       36.039421
# 4  92.907692   93.276923       0.063231    58374.030769       67.899846
# 5  96.700000   97.033333       0.073333    92484.533333        3.696667
#
#    Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                     2.814286                  2.942857   9.885714
# 1                     2.533333                  2.659259  10.714815
# 2                     1.527119                  1.528814  10.944633
# 3                     0.918533                  0.864479  11.453668
# 4                     0.798462                  0.689231  12.430769
# 5                     0.753333                  0.676667  12.106667
#
#    Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 0                       1.0                        0.0        71.785714
# 1                       1.0                        0.0        73.066667
# 2                       1.0                        0.0        76.864407
# 3                       1.0                        0.0        80.267954
# 4                       1.0                        0.0        80.106154
# 5                       1.0                        0.0        80.866667

# %%
#range = $0 to $112,418 for Undeveloped Countries
size_bins = [0, 5000, 10000, 25000, 50000, 75000, 115000]
category_labels = ["<$5,000", "$5,000-$10,000", "$10,000-$25,000","$25,000-$50,000","$50,000-$75,000","$75,000-$115,000"]

undeveloped["GDP Ranges"] = pd.cut(undeveloped["GDP_per_capita"],
                                                             size_bins, labels = category_labels)
undeveloped_gdp_ranges = undeveloped.groupby("GDP Ranges").mean(numeric_only = True)
undeveloped_gdp_ranges.reset_index(inplace = True)
undeveloped_gdp_ranges
# Out:
# /var/folders/xl/xk0yxcr97yv5qf0v1jxr20p80000gn/T/ipykernel_94698/168672267.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   undeveloped["GDP Ranges"] = pd.cut(undeveloped["GDP_per_capita"],
#          GDP Ranges         Year  Infant_deaths  Under_five_deaths  \
# 0           <$5,000  2007.163175      46.012508          66.752762
# 1    $5,000-$10,000  2008.271100      18.889770          23.638619
# 2   $10,000-$25,000  2008.590476      16.819524          20.541905
# 3   $25,000-$50,000  2007.558824       8.605882          10.202941
# 4   $50,000-$75,000  2007.357143       7.460714           8.735714
# 5  $75,000-$115,000          NaN            NaN                NaN
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B    Measles        BMI  \
# 0       247.388305             2.797658    79.811429  70.514286  24.117905
# 1       171.083877             5.377228    90.606138  79.347826  25.843478
# 2       136.593017             5.278519    90.900000  87.380952  26.548095
# 3       101.424088             2.971735    96.191176  91.338235  26.880882
# 4        67.712554             1.371786    94.535714  93.535714  27.228571
# 5              NaN                  NaN          NaN        NaN        NaN
#
#        Polio  Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0  80.940952   80.610159       1.267625     1997.520000       41.401956
# 1  90.943734   90.897698       0.921662     7135.030691       54.970639
# 2  91.900000   90.842857       0.676429    14890.866667        9.314571
# 3  96.470588   96.647059       0.231324    35527.176471        2.640147
# 4  95.500000   94.464286       0.076786    58347.428571        2.765357
# 5        NaN         NaN            NaN             NaN             NaN
#
#    Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 0                     6.407048                  6.489714   5.819302
# 1                     4.518414                  4.529412   8.431969
# 2                     4.524286                  4.520952   8.544286
# 3                     3.851471                  3.654412   9.089706
# 4                     4.528571                  4.253571   9.321429
# 5                          NaN                       NaN        NaN
#
#    Economy_status_Developed  Economy_status_Developing  Life_expectancy
# 0                       0.0                        1.0        63.427619
# 1                       0.0                        1.0        71.714322
# 2                       0.0                        1.0        73.812381
# 3                       0.0                        1.0        74.919118
# 4                       0.0                        1.0        78.375000
# 5                       NaN                        NaN              NaN

# %%
merged_df = pd.merge(developed_gdp_ranges,undeveloped_gdp_ranges, on = 'GDP Ranges')
merged_df
# Out:
#          GDP Ranges       Year_x  Infant_deaths_x  Under_five_deaths_x  \
# 0           <$5,000  2001.571429        14.442857            17.357143
# 1    $5,000-$10,000  2005.388889         9.272222            11.053704
# 2   $10,000-$25,000  2008.372881         4.623729             5.540678
# 3   $25,000-$50,000  2007.084942         3.867181             4.702317
# 4   $50,000-$75,000  2008.800000         4.023077             4.803077
# 5  $75,000-$115,000  2008.300000         3.226667             3.850000
#
#    Adult_mortality_x  Alcohol_consumption_x  Hepatitis_B_x  Measles_x  \
# 0         163.055000              10.688571      94.428571  88.571429
# 1         162.483398              10.400185      95.907407  94.407407
# 2         114.559331              11.090847      92.661017  91.141243
# 3          74.636098               9.433012      81.938224  85.625483
# 4          77.016023               8.894769      89.753846  87.615385
# 5          69.070150              10.946667      90.333333  84.300000
#
#        BMI_x    Polio_x  ...  Diphtheria_y  Incidents_HIV_y  GDP_per_capita_y  \
# 0  25.242857  95.714286  ...     80.610159         1.267625       1997.520000
# 1  25.833333  95.500000  ...     90.897698         0.921662       7135.030691
# 2  26.383616  95.661017  ...     90.842857         0.676429      14890.866667
# 3  25.882239  94.447876  ...     96.647059         0.231324      35527.176471
# 4  26.533846  92.907692  ...     94.464286         0.076786      58347.428571
# 5  25.620000  96.700000  ...           NaN              NaN               NaN
#
#    Population_mln_y  Thinness_ten_nineteen_years_y  \
# 0         41.401956                       6.407048
# 1         54.970639                       4.518414
# 2          9.314571                       4.524286
# 3          2.640147                       3.851471
# 4          2.765357                       4.528571
# 5               NaN                            NaN
#
#    Thinness_five_nine_years_y  Schooling_y  Economy_status_Developed_y  \
# 0                    6.489714     5.819302                         0.0
# 1                    4.529412     8.431969                         0.0
# 2                    4.520952     8.544286                         0.0
# 3                    3.654412     9.089706                         0.0
# 4                    4.253571     9.321429                         0.0
# 5                         NaN          NaN                         NaN
#
#    Economy_status_Developing_y  Life_expectancy_y
# 0                          1.0          63.427619
# 1                          1.0          71.714322
# 2                          1.0          73.812381
# 3                          1.0          74.919118
# 4                          1.0          78.375000
# 5                          NaN                NaN
#
# [6 rows x 39 columns]

# %%
plt.figure(figsize = (10,10))
ax = sns.barplot(data = gdp_ranges_df, x = "GDP Ranges", y = "Life_expectancy", hue = "Economy_status_Developed")
handles, labels = ax.get_legend().legendHandles, ["Undeveloped Regions", "Developed Regions"]
plt.legend(handles = handles, labels = labels)
plt.xticks(rotation = 90)
plt.title("Average Life Expectancy vs GDP Per Capita")
plt.xlabel('GDP per Capita Ranges')
plt.ylabel('Average Life Expectancy')
plt.tight_layout()
plt.savefig("../Group_Project1/Fig4.png")
plt.show()
# Out:
# /var/folders/xl/xk0yxcr97yv5qf0v1jxr20p80000gn/T/ipykernel_94698/1311108638.py:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles, labels = ax.get_legend().legendHandles, ["Undeveloped Regions", "Developed Regions"]

# %%
plt.scatter(life_expectancy['Schooling'],life_expectancy['GDP_per_capita'], life_expectancy['Economy_status_Developed'], label = 'Developed Regions')
plt.scatter(life_expectancy['Schooling'],life_expectancy['GDP_per_capita'], life_expectancy['Economy_status_Developing'], label = 'Undeveloped Regions')
plt.xlabel('Schooling')
plt.ylabel('GDP per Capita')
plt.title('Average Education Vs. GDP Per Capita')
plt.legend(loc = 'upper left')
plt.tight_layout()
plt.savefig("../Group_Project1/Fig5.png")
plt.show()

# %%
plt.figure(figsize = (10,10))
ax = sns.barplot(data = life_expectancy, x = "Region", y = "Schooling", hue = "Economy_status_Developed")
handles, labels = ax.get_legend().legendHandles, ["Undeveloped Regions", "Developed Regions"]
plt.legend(handles = handles, labels = labels)
plt.xticks(rotation = 90)
plt.title("Regions vs Years of Schooling")
plt.xlabel('Regions')
plt.ylabel('Years of Schooling')
plt.tight_layout()
plt.savefig("../Group_Project1/Fig6.png")
plt.show()
# Out:
# /var/folders/xl/xk0yxcr97yv5qf0v1jxr20p80000gn/T/ipykernel_94698/1018229234.py:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles, labels = ax.get_legend().legendHandles, ["Undeveloped Regions", "Developed Regions"]

# %%
plt.figure(figsize = (10,10))
ax = sns.barplot(data = life_expectancy, x = "Region", y = "BMI", hue = "Economy_status_Developed")
handles, labels = ax.get_legend().legendHandles, ["Undeveloped Regions", "Developed Regions"]
plt.legend(handles = handles, labels = labels)
plt.xticks(rotation = 90)
plt.title('BMI by Region')
plt.xlabel('Regions')
plt.ylabel('BMI')
plt.tight_layout()
plt.savefig("../Group_Project1/Fig7.png")
plt.show()
# Out:
# /var/folders/xl/xk0yxcr97yv5qf0v1jxr20p80000gn/T/ipykernel_94698/847945643.py:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles, labels = ax.get_legend().legendHandles, ["Undeveloped Regions", "Developed Regions"]

# %%
#line chart for showing average life expectancy by region over time
life_expectancy_new_df = life_expectancy[['Region', 'Year','Life_expectancy']]
life_expectancy_new_df
# Out:
#               Region  Year  Life_expectancy
# 0        Middle East  2015             76.5
# 1     European Union  2015             82.8
# 2               Asia  2007             65.4
# 3      South America  2006             67.0
# 4        Middle East  2012             81.7
# ...              ...   ...              ...
# 2859          Africa  2000             49.9
# 2860            Asia  2009             66.9
# 2861            Asia  2004             74.3
# 2862  European Union  2002             71.8
# 2863  Rest of Europe  2011             82.4
#
# [2864 rows x 3 columns]

# %%
life_expectancy_by_region = life_expectancy_new_df.groupby(["Region","Year"]).mean()
life_expectancy_by_region_df = life_expectancy_by_region.reset_index()

# %%
life_expectancy_africa = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "Africa"]
life_expectancy_africa
# Out:
#     Region  Year  Life_expectancy
# 0   Africa  2000        54.137255
# 1   Africa  2001        54.358824
# 2   Africa  2002        54.594118
# 3   Africa  2003        54.964706
# 4   Africa  2004        55.450980
# 5   Africa  2005        55.956863
# 6   Africa  2006        56.570588
# 7   Africa  2007        57.243137
# 8   Africa  2008        57.933333
# 9   Africa  2009        58.627451
# 10  Africa  2010        59.331373
# 11  Africa  2011        59.998039
# 12  Africa  2012        60.701961
# 13  Africa  2013        61.309804
# 14  Africa  2014        61.911765
# 15  Africa  2015        62.466667

# %%
life_expectancy_me = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "Middle East"]
life_expectancy_me
# Out:
#          Region  Year  Life_expectancy
# 64  Middle East  2000        72.307143
# 65  Middle East  2001        72.600000
# 66  Middle East  2002        72.857143
# 67  Middle East  2003        73.114286
# 68  Middle East  2004        73.364286
# 69  Middle East  2005        73.585714
# 70  Middle East  2006        73.828571
# 71  Middle East  2007        73.985714
# 72  Middle East  2008        74.192857
# 73  Middle East  2009        74.378571
# 74  Middle East  2010        74.535714
# 75  Middle East  2011        74.685714
# 76  Middle East  2012        74.807143
# 77  Middle East  2013        74.978571
# 78  Middle East  2014        75.114286
# 79  Middle East  2015        75.271429

# %%
life_expectancy_eu = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "European Union"]
life_expectancy_eu
# Out:
#             Region  Year  Life_expectancy
# 48  European Union  2000        75.740741
# 49  European Union  2001        76.092593
# 50  European Union  2002        76.237037
# 51  European Union  2003        76.366667
# 52  European Union  2004        76.870370
# 53  European Union  2005        76.974074
# 54  European Union  2006        77.251852
# 55  European Union  2007        77.422222
# 56  European Union  2008        77.777778
# 57  European Union  2009        78.081481
# 58  European Union  2010        78.400000
# 59  European Union  2011        78.874074
# 60  European Union  2012        78.937037
# 61  European Union  2013        79.288889
# 62  European Union  2014        79.614815
# 63  European Union  2015        79.511111

# %%
life_expectancy_asia = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "Asia"]
life_expectancy_asia
# Out:
#    Region  Year  Life_expectancy
# 16   Asia  2000        66.648148
# 17   Asia  2001        67.048148
# 18   Asia  2002        67.440741
# 19   Asia  2003        67.833333
# 20   Asia  2004        68.233333
# 21   Asia  2005        68.596296
# 22   Asia  2006        68.955556
# 23   Asia  2007        69.325926
# 24   Asia  2008        69.711111
# 25   Asia  2009        70.125926
# 26   Asia  2010        70.433333
# 27   Asia  2011        70.737037
# 28   Asia  2012        71.088889
# 29   Asia  2013        71.403704
# 30   Asia  2014        71.714815
# 31   Asia  2015        71.981481

# %%
life_expectancy_sa = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "South America"]
life_expectancy_sa
# Out:
#             Region  Year  Life_expectancy
# 128  South America  2000        70.808333
# 129  South America  2001        71.100000
# 130  South America  2002        71.383333
# 131  South America  2003        71.650000
# 132  South America  2004        71.941667
# 133  South America  2005        72.216667
# 134  South America  2006        72.475000
# 135  South America  2007        72.733333
# 136  South America  2008        72.991667
# 137  South America  2009        73.241667
# 138  South America  2010        73.483333
# 139  South America  2011        73.700000
# 140  South America  2012        73.916667
# 141  South America  2013        74.108333
# 142  South America  2014        74.275000
# 143  South America  2015        74.466667

# %%
life_expectancy_cac = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "Central America and Caribbean"]
life_expectancy_cac
# Out:
#                            Region  Year  Life_expectancy
# 32  Central America and Caribbean  2000        70.847368
# 33  Central America and Caribbean  2001        71.094737
# 34  Central America and Caribbean  2002        71.310526
# 35  Central America and Caribbean  2003        71.542105
# 36  Central America and Caribbean  2004        71.742105
# 37  Central America and Caribbean  2005        71.957895
# 38  Central America and Caribbean  2006        72.157895
# 39  Central America and Caribbean  2007        72.357895
# 40  Central America and Caribbean  2008        72.568421
# 41  Central America and Caribbean  2009        72.763158
# 42  Central America and Caribbean  2010        72.952632
# 43  Central America and Caribbean  2011        73.168421
# 44  Central America and Caribbean  2012        73.347368
# 45  Central America and Caribbean  2013        73.547368
# 46  Central America and Caribbean  2014        73.726316
# 47  Central America and Caribbean  2015        73.915789

# %%
life_expectancy_rest_eu = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "Rest of Europe"]
life_expectancy_rest_eu
# Out:
#              Region  Year  Life_expectancy
# 112  Rest of Europe  2000        72.813333
# 113  Rest of Europe  2001        73.080000
# 114  Rest of Europe  2002        73.140000
# 115  Rest of Europe  2003        73.320000
# 116  Rest of Europe  2004        73.586667
# 117  Rest of Europe  2005        73.726667
# 118  Rest of Europe  2006        73.966667
# 119  Rest of Europe  2007        74.246667
# 120  Rest of Europe  2008        74.533333
# 121  Rest of Europe  2009        74.793333
# 122  Rest of Europe  2010        75.153333
# 123  Rest of Europe  2011        75.513333
# 124  Rest of Europe  2012        75.806667
# 125  Rest of Europe  2013        76.053333
# 126  Rest of Europe  2014        76.293333
# 127  Rest of Europe  2015        76.380000

# %%
life_expectancy_ocean = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "Oceania"]
life_expectancy_ocean
# Out:
#       Region  Year  Life_expectancy
# 96   Oceania  2000        67.518182
# 97   Oceania  2001        67.809091
# 98   Oceania  2002        68.109091
# 99   Oceania  2003        68.418182
# 100  Oceania  2004        68.700000
# 101  Oceania  2005        69.018182
# 102  Oceania  2006        69.263636
# 103  Oceania  2007        69.527273
# 104  Oceania  2008        69.754545
# 105  Oceania  2009        69.990909
# 106  Oceania  2010        70.200000
# 107  Oceania  2011        70.400000
# 108  Oceania  2012        70.600000
# 109  Oceania  2013        70.818182
# 110  Oceania  2014        70.981818
# 111  Oceania  2015        71.172727

# %%
life_expectancy_na = life_expectancy_by_region_df.loc[life_expectancy_by_region_df['Region'] == "North America"]
life_expectancy_na
# Out:
#            Region  Year  Life_expectancy
# 80  North America  2000        76.666667
# 81  North America  2001        76.933333
# 82  North America  2002        77.100000
# 83  North America  2003        77.266667
# 84  North America  2004        77.533333
# 85  North America  2005        77.666667
# 86  North America  2006        77.766667
# 87  North America  2007        77.933333
# 88  North America  2008        77.966667
# 89  North America  2009        78.166667
# 90  North America  2010        78.266667
# 91  North America  2011        78.333333
# 92  North America  2012        78.433333
# 93  North America  2013        78.433333
# 94  North America  2014        78.500000
# 95  North America  2015        78.500000

# %%
#line chart for showing average life expectancy by region over time

plt.figure(figsize = (15,15))
plt.plot(life_expectancy_africa['Year'],life_expectancy_africa['Life_expectancy'],label = "Africa")
plt.plot(life_expectancy_me['Year'],life_expectancy_me['Life_expectancy'], label = "Middle East")
plt.plot(life_expectancy_eu['Year'],life_expectancy_eu['Life_expectancy'], label = "European Union")
plt.plot(life_expectancy_asia['Year'],life_expectancy_asia['Life_expectancy'], label = "Asia")
plt.plot(life_expectancy_sa['Year'],life_expectancy_sa['Life_expectancy'], label = "South America")
plt.plot(life_expectancy_cac['Year'],life_expectancy_cac['Life_expectancy'], label = "Central America and Caribbean")
plt.plot(life_expectancy_rest_eu['Year'],life_expectancy_rest_eu['Life_expectancy'], label = "Rest of Europe")
plt.plot(life_expectancy_ocean['Year'],life_expectancy_ocean['Life_expectancy'], label = "Oceania")
plt.plot(life_expectancy_na['Year'],life_expectancy_na['Life_expectancy'], label = "North America")

plt.title("Average Life Expectancy over the Years by Region")
plt.xlabel("Years")
plt.ylabel("Life Expectancy")
plt.legend(loc = 'lower right')
plt.tight_layout()
plt.savefig("../Group_Project1/Fig8.png")
plt.show()
